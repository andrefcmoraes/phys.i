# %% [markdown]
# <a href="https://colab.research.google.com/github/andrefcmoraes/phys.i/blob/main/FreeFall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UNIVERSIDADE ESTADUAL DO MARANHÃO (UEMA)
# # CENTRO DE CIÊNCIAS TECNOLÓGICAS (CCT)
#
# > Fundamentos de Mecânica

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data0.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((0,11))
plt.xlim((2.5,3.5))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,7 m, variação de tempo de apróximadamente 0,377 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data1.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((0,11))
plt.xlim((1,1.7))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,7 m, variação de tempo de apróximadamente 0,378 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data2.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.5,2))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,7 m, variação de tempo de apróximadamente 0,38 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data3.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((4.50,5))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,8 m, variação de tempo de apróximadamente 0,39 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data4.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1,1.8))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,7 m, com adição de 130 gramas pudemos notar ainda a mesma variação proxima de de 0,39 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data5.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.8,2.3))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,7 m, com adição de 1 Kg pudemos notar ainda a mesma variação próxima de 0,375 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data6.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((0.1,0.7))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 1,3 m e variação do tempo em torno de 0,60 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data7.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((0.3,1))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 1,3 m e variação do tempo em torno de 0,57 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data8.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((0.3,1))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 1,3 m e variação do tempo em torno de 0,57 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data9.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.70,2.20))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,8 m, variação de tempo de apróximadamente 0,43 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data10.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.35,1.8))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# h = 0,8 m, variação de tempo de apróximadamente 0,42 segundos
