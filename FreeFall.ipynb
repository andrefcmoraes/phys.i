# %% [markdown]
# <a href="https://colab.research.google.com/github/andrefcmoraes/phys.i/blob/main/FreeFall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data0.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((0,11))
plt.xlim((2.5,3.5))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# Um variação de tempo próxima de 0.4 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data1.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((0,11))
plt.xlim((1,1.7))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# Variação de tempo em queda proximo de 0,4 segundos.

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data2.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.5,2))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# Também temos uma variação próxima de 0,4 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data4.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1,1.8))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# Com adição de 130 gramas pudemos notar ainda a mesma variação proxima de de 0,4 segundos

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://raw.githubusercontent.com/andrefcmoraes/phys.i/main/Raw%20Data5.csv")
df.head()
df.plot(x ='Time (s)', y='Acceleration z (m/s^2)')
plt.ylim((-5,11))
plt.xlim((1.8,2.3))
plt.ylabel('Aceleração em (m/s^2)')
plt.xlabel('Tempo em (s)')
plt.grid()
plt.show()

# %% [markdown]
# Com adição de 1 Kg pudemos notar ainda a mesma variação próxima de 0,4 segundos
